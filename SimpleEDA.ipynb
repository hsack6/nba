# %% [markdown]
# # Simple NBA EDA
# 参考 https://www.kaggle.com/ash316/simple-nba-eda

# %%
import pandas as pd
import matplotlib.pyplot as plt
DataDir = "/home/onimem/work/Open_world/NBA/original"

from subprocess import check_output
print(check_output(["ls", DataDir]).decode("utf8"))
# Out:
# Players.csv
# Seasons_Stats.csv
# player_data.csv

# %% [markdown]
# # Players.csv Analysis
# ## 整形＆欠損値処理

# %%
players=pd.read_csv(DataDir + '/Players.csv')
print(players.shape)
players.head()
# Out:
# (3922, 8)
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
players.isnull().sum()
# Out:
# Unnamed: 0       0
# Player           1
# height           1
# weight           1
# collage        349
# born             1
# birth_city     470
# birth_state    483
# dtype: int64

# %%
players.drop('Unnamed: 0', axis=1, inplace=True)
print(players.shape)
players.head()
# Out:
# (3922, 7)
#             Player  height  weight                          collage    born  \
# 0  Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1     Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2    Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3       Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4      Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#     birth_city birth_state
# 0          NaN         NaN
# 1     Yorktown     Indiana
# 2          NaN         NaN
# 3          NaN         NaN
# 4  Hardinsburg    Kentucky

# %%
players.dropna(how='all',inplace=True)
print(players.shape)
players.isnull().sum()
# Out:
# (3921, 7)
# Player           0
# height           0
# weight           0
# collage        348
# born             0
# birth_city     469
# birth_state    482
# dtype: int64

# %%
players.set_index('Player',inplace=True)
print(players.shape)
players.head()
# Out:
# (3921, 6)
#                  height  weight                          collage    born  \
# Player
# Curly Armstrong   180.0    77.0               Indiana University  1918.0
# Cliff Barker      188.0    83.0           University of Kentucky  1921.0
# Leo Barnhorst     193.0    86.0         University of Notre Dame  1924.0
# Ed Bartels        196.0    88.0  North Carolina State University  1925.0
# Ralph Beard       178.0    79.0           University of Kentucky  1927.0
#
#                   birth_city birth_state
# Player
# Curly Armstrong          NaN         NaN
# Cliff Barker        Yorktown     Indiana
# Leo Barnhorst            NaN         NaN
# Ed Bartels               NaN         NaN
# Ralph Beard      Hardinsburg    Kentucky

# %% [markdown]
# ## Basic Analysis

# %%
max_value = players['height'].max()
max_key = players['height'].idxmax()
print(max_key, max_value)
players.loc[max_key : max_key, :]
# Out:
# Manute Bol 231.0
#             height  weight                   collage    born birth_city  \
# Player
# Manute Bol   231.0    90.0  University of Bridgeport  1962.0    Gogrial
#
#             birth_state
# Player
# Manute Bol  South Sudan

# %%
min_value = players['height'].min()
min_key = players['height'].idxmin()
print(min_key, min_value)
players.loc[min_key : min_key, :]
# Out:
# Muggsy Bogues 160.0
#                height  weight                 collage    born birth_city  \
# Player
# Muggsy Bogues   160.0    61.0  Wake Forest University  1965.0  Baltimore
#
#               birth_state
# Player
# Muggsy Bogues    Maryland

# %%
print(players.mean()['height'])
# same → print(players['height'].mean())
# Out:
# 198.7082376944657

# %%
bins=range(150, 250, 10)
plt.hist(players["height"],bins,histtype="bar",rwidth=1.2,color='#0ff0ff')
plt.xlabel('Height in Cm')
plt.ylabel('Count')
plt.axvline(players["height"].mean(), color='b', linestyle='dashed', linewidth=2)
plt.plot()
# Out:
# []

# %%
players.groupby(['collage']).count()
# players.groupby(['collage']) → <pandas.core.groupby.groupby.DataFrameGroupBy object at 0x7f34140f2a90>
# Out:
#                                                   height  weight  born  \
# collage
# Acadia University                                      1       1     1
# Alabama A&M University                                 1       1     1
# Alabama State University                               1       1     1
# Albany State University                                4       4     4
# Alcorn State University                                4       4     4
# Alliance College                                       1       1     1
# American International College                         1       1     1
# American University                                    1       1     1
# Appalachian State University                           1       1     1
# Arizona State University                              21      21    21
# Assumption College                                     2       2     2
# Auburn University                                     16      16    16
# Auburn University at Montgomery                        2       2     2
# Augsburg College                                       3       3     3
# Augusta State University                               1       1     1
# Augustana College (SD)                                 2       2     2
# Aurora University                                      1       1     1
# Austin Peay State University                           5       5     5
# Averett University                                     1       1     1
# Ball State University                                  2       2     2
# Barton County Community College                        1       1     1
# Baylor University                                     11      11    11
# Belmont Abbey College                                  1       1     1
# Belmont University                                     1       1     1
# Beloit College                                         1       1     1
# Bemidji State University                               2       2     2
# Bethel College                                         1       1     1
# Blinn College                                          1       1     1
# Boise State University                                 3       3     3
# Boston College                                        18      18    18
# ...                                                  ...     ...   ...
# Voorhees College                                       1       1     1
# Wake Forest University                                29      29    29
# Walsh University                                       1       1     1
# Washington & Jefferson College                         1       1     1
# Washington State University                           12      12    12
# Wayne State University                                 2       2     2
# Weber State University                                 7       7     7
# West Texas A&M University                              4       4     4
# West Virginia State University                         4       4     4
# West Virginia University                              14      14    14
# West Virginia University Institute of Technology       1       1     1
# West Virginia Wesleyan College                         1       1     1
# Westchester CC                                         1       1     1
# Western Carolina University                            3       3     3
# Western Illinois University                            1       1     1
# Western Kentucky University                           24      24    24
# Western Michigan University                            6       6     6
# Wheaton College                                        1       1     1
# Whitworth                                              2       2     2
# Wichita State University                              11      11    11
# Wilberforce University                                 1       1     1
# William Paterson University                            2       2     2
# Wingate University                                     1       1     1
# Winston-Salem State University                         5       5     5
# Wofford College                                        1       1     1
# Wright State University                                2       2     2
# Xavier University                                     16      16    16
# Xavier University of Louisiana                         3       3     3
# Yale University                                        2       2     2
# Youngstown State University                            1       1     1
#
#                                                   birth_city  birth_state
# collage
# Acadia University                                          0            0
# Alabama A&M University                                     1            1
# Alabama State University                                   1            1
# Albany State University                                    4            4
# Alcorn State University                                    4            4
# Alliance College                                           1            1
# American International College                             1            1
# American University                                        1            1
# Appalachian State University                               1            1
# Arizona State University                                  20           20
# Assumption College                                         0            0
# Auburn University                                         16           16
# Auburn University at Montgomery                            2            2
# Augsburg College                                           3            3
# Augusta State University                                   1            1
# Augustana College (SD)                                     2            2
# Aurora University                                          1            1
# Austin Peay State University                               5            5
# Averett University                                         1            1
# Ball State University                                      2            2
# Barton County Community College                            1            1
# Baylor University                                         10           10
# Belmont Abbey College                                      1            1
# Belmont University                                         1            1
# Beloit College                                             1            1
# Bemidji State University                                   2            2
# Bethel College                                             0            0
# Blinn College                                              1            1
# Boise State University                                     3            3
# Boston College                                            17           17
# ...                                                      ...          ...
# Voorhees College                                           0            0
# Wake Forest University                                    27           27
# Walsh University                                           1            1
# Washington & Jefferson College                             1            1
# Washington State University                               11           11
# Wayne State University                                     0            0
# Weber State University                                     5            5
# West Texas A&M University                                  4            4
# West Virginia State University                             1            1
# West Virginia University                                  12           12
# West Virginia University Institute of Technology           1            1
# West Virginia Wesleyan College                             1            1
# Westchester CC                                             1            1
# Western Carolina University                                3            3
# Western Illinois University                                0            0
# Western Kentucky University                               14           14
# Western Michigan University                                6            6
# Wheaton College                                            1            1
# Whitworth                                                  1            1
# Wichita State University                                  10           10
# Wilberforce University                                     1            1
# William Paterson University                                2            2
# Wingate University                                         1            1
# Winston-Salem State University                             4            4
# Wofford College                                            0            0
# Wright State University                                    2            2
# Xavier University                                         14           14
# Xavier University of Louisiana                             3            3
# Yale University                                            2            2
# Youngstown State University                                1            0
#
# [422 rows x 5 columns]

# %%
players.groupby(['collage'])['height'].count().reset_index()
# Out:
#                                               collage  height
# 0                                   Acadia University       1
# 1                              Alabama A&M University       1
# 2                            Alabama State University       1
# 3                             Albany State University       4
# 4                             Alcorn State University       4
# 5                                    Alliance College       1
# 6                      American International College       1
# 7                                 American University       1
# 8                        Appalachian State University       1
# 9                            Arizona State University      21
# 10                                 Assumption College       2
# 11                                  Auburn University      16
# 12                    Auburn University at Montgomery       2
# 13                                   Augsburg College       3
# 14                           Augusta State University       1
# 15                             Augustana College (SD)       2
# 16                                  Aurora University       1
# 17                       Austin Peay State University       5
# 18                                 Averett University       1
# 19                              Ball State University       2
# 20                    Barton County Community College       1
# 21                                  Baylor University      11
# 22                              Belmont Abbey College       1
# 23                                 Belmont University       1
# 24                                     Beloit College       1
# 25                           Bemidji State University       2
# 26                                     Bethel College       1
# 27                                      Blinn College       1
# 28                             Boise State University       3
# 29                                     Boston College      18
# ..                                                ...     ...
# 392                                  Voorhees College       1
# 393                            Wake Forest University      29
# 394                                  Walsh University       1
# 395                    Washington & Jefferson College       1
# 396                       Washington State University      12
# 397                            Wayne State University       2
# 398                            Weber State University       7
# 399                         West Texas A&M University       4
# 400                    West Virginia State University       4
# 401                          West Virginia University      14
# 402  West Virginia University Institute of Technology       1
# 403                    West Virginia Wesleyan College       1
# 404                                    Westchester CC       1
# 405                       Western Carolina University       3
# 406                       Western Illinois University       1
# 407                       Western Kentucky University      24
# 408                       Western Michigan University       6
# 409                                   Wheaton College       1
# 410                                         Whitworth       2
# 411                          Wichita State University      11
# 412                            Wilberforce University       1
# 413                       William Paterson University       2
# 414                                Wingate University       1
# 415                    Winston-Salem State University       5
# 416                                   Wofford College       1
# 417                           Wright State University       2
# 418                                 Xavier University      16
# 419                    Xavier University of Louisiana       3
# 420                                   Yale University       2
# 421                       Youngstown State University       1
#
# [422 rows x 2 columns]

# %%
# ascending=False 降順
college = players.groupby(['collage'])['height'].count().reset_index().sort_values(by='height',ascending=False)[:10]
players.groupby(['collage'])['height'].count().reset_index().sort_values(by='height',ascending=False)[:10]
# Out:
#                                    collage  height
# 311                 University of Kentucky      89
# 289  University of California, Los Angeles      86
# 335           University of North Carolina      68
# 310                   University of Kansas      59
# 78                         Duke University      56
# 341               University of Notre Dame      51
# 126                     Indiana University      49
# 259                    Syracuse University      49
# 250                  St. John's University      48
# 314               University of Louisville      46

# %%
college.set_index('collage', inplace=True)
college
# Out:
#                                        height
# collage
# University of Kentucky                     89
# University of California, Los Angeles      86
# University of North Carolina               68
# University of Kansas                       59
# Duke University                            56
# University of Notre Dame                   51
# Indiana University                         49
# Syracuse University                        49
# St. John's University                      48
# University of Louisville                   46

# %%
college.columns = ['Count']
college
# Out:
#                                        Count
# collage
# University of Kentucky                    89
# University of California, Los Angeles     86
# University of North Carolina              68
# University of Kansas                      59
# Duke University                           56
# University of Notre Dame                  51
# Indiana University                        49
# Syracuse University                       49
# St. John's University                     48
# University of Louisville                  46

# %%
ax=college.plot.bar(width=0.8)

# %%
ax=college.plot.bar(width=0.8)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.15, p.get_height()+0.35))
plt.show()

# %%
city=players.groupby(['birth_state'])['height'].count().reset_index().sort_values(by='height',ascending=False)[:10]
city.set_index('birth_state',inplace=True)
city.columns=['Count']
ax=city.plot.bar(width=0.8,color='#ab1abf')
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))
plt.show()

# %% [markdown]
# # Seasons_Stats.csv Analysis
# ## 整形＆欠損値処理

# %%
Seasons=pd.read_csv(DataDir + '/Seasons_Stats.csv')
print(Seasons.shape)
Seasons.head()
# Out:
# (24691, 53)
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
Seasons.drop('Unnamed: 0',axis=1,inplace=True)

# %%
Seasons.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
Seasons.isnull().sum()
# Out:
# Year         67
# Player       67
# Pos          67
# Age          75
# Tm           67
# G            67
# GS         6458
# MP          553
# PER         590
# TS%         153
# 3PAr       5852
# FTr         166
# ORB%       3899
# DRB%       3899
# TRB%       3120
# AST%       2136
# STL%       3899
# BLK%       3899
# TOV%       5109
# USG%       5051
# blanl     24691
# OWS         106
# DWS         106
# WS          106
# WS/48       590
# blank2    24691
# OBPM       3894
# DBPM       3894
# BPM        3894
# VORP       3894
# FG           67
# FGA          67
# FG%         166
# 3P         5764
# 3PA        5764
# 3P%        9275
# 2P           67
# 2PA          67
# 2P%         195
# eFG%        166
# FT           67
# FTA          67
# FT%         925
# ORB        3894
# DRB        3894
# TRB         379
# AST          67
# STL        3894
# BLK        3894
# TOV        5046
# PF           67
# PTS          67
# dtype: int64

# %%
# Seasons['Player'].notnull()
Seasons['Player'].notnull().sum()
# Out:
# 24624

# %%
# We can see that 67 rows have no player names. We need to drop these.
Seasons=Seasons[Seasons['Player'].notnull()] #removing entries without names
print(Seasons.shape)
Seasons.isnull().sum()
# Out:
# (24624, 52)
# Year          0
# Player        0
# Pos           0
# Age           8
# Tm            0
# G             0
# GS         6391
# MP          486
# PER         523
# TS%          86
# 3PAr       5785
# FTr          99
# ORB%       3832
# DRB%       3832
# TRB%       3053
# AST%       2069
# STL%       3832
# BLK%       3832
# TOV%       5042
# USG%       4984
# blanl     24624
# OWS          39
# DWS          39
# WS           39
# WS/48       523
# blank2    24624
# OBPM       3827
# DBPM       3827
# BPM        3827
# VORP       3827
# FG            0
# FGA           0
# FG%          99
# 3P         5697
# 3PA        5697
# 3P%        9208
# 2P            0
# 2PA           0
# 2P%         128
# eFG%         99
# FT            0
# FTA           0
# FT%         858
# ORB        3827
# DRB        3827
# TRB         312
# AST           0
# STL        3827
# BLK        3827
# TOV        4979
# PF            0
# PTS           0
# dtype: int64
